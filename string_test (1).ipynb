# %% [markdown]
# #

# %%
name1="mehak"
name2="anshika"
string=name1+name2
print(string)
# Out:
# mehakanshika

# %%
# +operator is used for simply add two strings 
# join() method is used to join two lines with another character,symbol and alphabet
string="Hello","everyone"
text="@".join(string)
print(text)
# Out:
# Hello@everyone

# %%
#ques no.3
string="be happy"
print(string.find("happy"))
# Out:
# 3

# %%
# ques no.4
string="mehak"
print(len(string))
# Out:
# 5

# %%
# ques no.5
string="this is python class"
print(string.upper())
# Out:
# THIS IS PYTHON CLASS

# %%
#ques no.6
string="THIS IS PYTHON CLASS"
print(string.lower())
# Out:
# this is python class

# %%
# ques no. 7
string="hello, my name is mehak"
print(string.replace("mehak","anshika"))
# Out:
# hello, my name is anshika

# %%
#ques no.8
string="this is my python class"
print(string.split(" ",))
# Out:
# ['this', 'is', 'my', 'python', 'class']

# %%
#ques no.9
string="Never give up"
print(string.startswith("Never"))
# Out:
# True

# %%
#quesno.10
string="practice makes perfect"
print(string.endswith("perfect"))
# Out:
# True

# %%
# ques no.11
# with the help of .strip method
string="     this is python class   "
print(string.strip())
# Out:
# this is python class

# %%
#ques no.12
string="this is python class"
print(string.index("i"))
# Out:
# 2

# %%
#ques no.13
string="this is my python class python"
print(string.count("python"))
# Out:
# 2

# %%
#ques no.14
string="hello"
print(string.isalpha())
# Out:
# True

# %%
#ques no.15
string="23"
print(string.isnumeric())
# Out:
# True

# %%
#ques no.17
string="pythonclass"
print(string[::-1])
# Out:
# ssalcnohtyp

# %%
#ques no.18
name="mehak"
age=20
string="my name is {} and i am {} years old".format(name,age)
print(string)
# Out:
# my name is mehak and i am 20 years old

# %%
#ques no.19
string="this is my python class"
print(string[0:17:])
# Out:
# this is my python

# %%
#ques no.20
string="this is java class"
print(string.replace("class",""))
# Out:
# this is java
